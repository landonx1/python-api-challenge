# %% [markdown]
# ## WeatherPy
#
# ### Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

from api_keys import geoapify_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the citipy Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 595

# %% [markdown]
# ### Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# Use the Open Weather Map API to retrieve weather data from the cities list generated in the starter code

# %%
# set base url
baseweatherUrl = "https://api.openweathermap.org/data/2.5/"
basegeoUrl= "https://api.geoapify.com/v2/"

weatherKey = weather_api_key
geoKey = geoapify_key

# def getGeodata(city, country, apiKey):
#     endpoint = f"https://api.geoapify.com/v1/geocode/search?apiKey={apiKey}&format=json&text={city}_{country}"
#     return endpoint

def getCityUrl(city, apiKey):
    endpoint = f"https://api.geoapify.com/v1/geocode/search?apiKey={apiKey}&format=json&text={city}&type=city"
    return endpoint
    
def getWeatherUrl(lat, lon, apiKey):
    endpoint = f"{baseweatherUrl}/weather?appid={apiKey}&units=imperial&q={city}"
    return endpoint

def getCityWeatherUrl(city, apikey):
    result = f"{baseweatherUrl}weather?appid={apikey}&units=imperial&q={city}"
    return result

# %% [markdown]
# ### City Data

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = getCityUrl(city,geoKey)

    #get weather endpoint
    weatherUrl = getCityWeatherUrl(city, weatherKey)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        cityData = requests.get(city_url).json()
        weatherData = requests.get(weatherUrl).json()

        city_weather = weatherData["main"]["temp"]

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = weatherData["coord"]["lat"]
        city_lng = weatherData["coord"]["lon"]
        city_max_temp = weatherData["main"]["temp_max"]
        city_humidity = weatherData["main"]["humidity"]
        city_clouds = weatherData["clouds"]["all"]
        city_wind = weatherData["wind"]["speed"]
        city_country = cityData["results"][0]["country"]
        city_date = weatherData["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Weather": city_weather,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print(f"City '{city}' not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ust-nera
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | cabedelo
# Processing Record 4 of Set 1 | edinburgh of the seven seas
# Processing Record 5 of Set 1 | kostomuksha
# Processing Record 6 of Set 1 | college
# Processing Record 7 of Set 1 | madang
# Processing Record 8 of Set 1 | margaret river
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | wailua homesteads
# Processing Record 11 of Set 1 | yanam
# Processing Record 12 of Set 1 | whitehorse
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | pitimbu
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | santiago de cao
# Processing Record 17 of Set 1 | juneau
# Processing Record 18 of Set 1 | constantia
# Processing Record 19 of Set 1 | port-aux-francais
# City not found. Skipping...
# Processing Record 20 of Set 1 | san patricio
# Processing Record 21 of Set 1 | papatowai
# Processing Record 22 of Set 1 | minas de marcona
# Processing Record 23 of Set 1 | alta
# Processing Record 24 of Set 1 | mumbwa
# Processing Record 25 of Set 1 | saipan
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | tofol
# Processing Record 28 of Set 1 | fortaleza
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | saldanha
# Processing Record 31 of Set 1 | iskateley
# Processing Record 32 of Set 1 | kayangel
# Processing Record 33 of Set 1 | isafjordur
# Processing Record 34 of Set 1 | yeraliyev
# Processing Record 35 of Set 1 | coyhaique
# Processing Record 36 of Set 1 | adamstown
# Processing Record 37 of Set 1 | aasiaat
# Processing Record 38 of Set 1 | newala kisimani
# Processing Record 39 of Set 1 | hawaiian paradise park
# Processing Record 40 of Set 1 | hirara
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | vila franca do campo
# Processing Record 43 of Set 1 | remire-montjoly
# Processing Record 44 of Set 1 | eydhafushi
# Processing Record 45 of Set 1 | mahina
# Processing Record 46 of Set 1 | broome
# Processing Record 47 of Set 1 | boa vista
# Processing Record 48 of Set 1 | stanley
# Processing Record 49 of Set 1 | port mathurin
# Processing Record 50 of Set 1 | albany
# Processing Record 0 of Set 2 | lompoc
# Processing Record 1 of Set 2 | sibolga
# Processing Record 2 of Set 2 | ambovombe
# Processing Record 3 of Set 2 | codrington
# Processing Record 4 of Set 2 | mananjary
# Processing Record 5 of Set 2 | mangai
# Processing Record 6 of Set 2 | greeley
# Processing Record 7 of Set 2 | aldan
# Processing Record 8 of Set 2 | alofi
# Processing Record 9 of Set 2 | turpan
# Processing Record 10 of Set 2 | dhidhdhoo
# Processing Record 11 of Set 2 | susuman
# Processing Record 12 of Set 2 | lihue
# Processing Record 13 of Set 2 | malanje
# Processing Record 14 of Set 2 | fort mcmurray
# Processing Record 15 of Set 2 | keflavik
# Processing Record 16 of Set 2 | concepcion del uruguay
# Processing Record 17 of Set 2 | west island
# Processing Record 18 of Set 2 | vernon
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | hastings
# Processing Record 21 of Set 2 | ekangala
# Processing Record 22 of Set 2 | thakhek
# Processing Record 23 of Set 2 | invercargill
# Processing Record 24 of Set 2 | utrik
# Processing Record 25 of Set 2 | grytviken
# Processing Record 26 of Set 2 | taoudenni
# Processing Record 27 of Set 2 | tura
# Processing Record 28 of Set 2 | mareeba
# Processing Record 29 of Set 2 | flying fish cove
# Processing Record 30 of Set 2 | tiksi
# Processing Record 31 of Set 2 | alo
# Processing Record 32 of Set 2 | klyuchi
# Processing Record 33 of Set 2 | moa
# Processing Record 34 of Set 2 | miyaly
# Processing Record 35 of Set 2 | afaahiti
# Processing Record 36 of Set 2 | kapa'a
# Processing Record 37 of Set 2 | cuyo
# Processing Record 38 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 39 of Set 2 | big bear lake
# Processing Record 40 of Set 2 | talnakh
# Processing Record 41 of Set 2 | nemuro
# Processing Record 42 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 43 of Set 2 | ubari
# Processing Record 44 of Set 2 | mount pleasant
# Processing Record 45 of Set 2 | puerto natales
# Processing Record 46 of Set 2 | neiafu
# Processing Record 47 of Set 2 | ilulissat
# Processing Record 48 of Set 2 | ibusuki
# Processing Record 49 of Set 2 | jakar
# Processing Record 0 of Set 3 | amga
# Processing Record 1 of Set 3 | waingapu
# Processing Record 2 of Set 3 | isfahan
# Processing Record 3 of Set 3 | uturoa
# Processing Record 4 of Set 3 | ko lanta
# Processing Record 5 of Set 3 | malango
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | bikenibeu village
# Processing Record 8 of Set 3 | delta del tigre
# Processing Record 9 of Set 3 | thompson
# Processing Record 32 of Set 4 | colonia
# Processing Record 33 of Set 4 | santa maria
# Processing Record 34 of Set 4 | lapua
# Processing Record 35 of Set 4 | santa fe do sul
# Processing Record 36 of Set 4 | okha
# Processing Record 37 of Set 4 | guarapari
# Processing Record 38 of Set 4 | ha'il
# Processing Record 39 of Set 4 | rengo
# Processing Record 40 of Set 4 | reggane
# Processing Record 41 of Set 4 | avarua
# Processing Record 42 of Set 4 | castillos
# Processing Record 43 of Set 4 | kurumkan
# Processing Record 44 of Set 4 | vilyuchinsk
# Processing Record 45 of Set 4 | fada
# Processing Record 46 of Set 4 | murun-kuren
# Processing Record 47 of Set 4 | tual
# Processing Record 48 of Set 4 | dutse
# Processing Record 49 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 0 of Set 5 | sao jose da coroa grande
# Processing Record 1 of Set 5 | east london
# Processing Record 2 of Set 5 | enewetak
# Processing Record 3 of Set 5 | port douglas
# Processing Record 4 of Set 5 | lesogorsk
# Processing Record 5 of Set 5 | marang
# Processing Record 6 of Set 5 | tralee
# Processing Record 7 of Set 5 | hadibu
# Processing Record 8 of Set 5 | vorgashor
# Processing Record 9 of Set 5 | wakkanai
# Processing Record 10 of Set 5 | kalavoor
# City not found. Skipping...
# Processing Record 11 of Set 5 | fort-shevchenko
# Processing Record 12 of Set 5 | hamilton
# Processing Record 13 of Set 5 | imbituba
# Processing Record 14 of Set 5 | seaside
# Processing Record 15 of Set 5 | long beach
# Processing Record 16 of Set 5 | bashtanka
# Processing Record 17 of Set 5 | kalix
# Processing Record 18 of Set 5 | villa gesell
# Processing Record 19 of Set 5 | piikkio
# Processing Record 20 of Set 5 | hithadhoo
# Processing Record 21 of Set 5 | porkhov
# Processing Record 22 of Set 5 | saidpur
# Processing Record 23 of Set 5 | sitka
# Processing Record 24 of Set 5 | ola
# Processing Record 25 of Set 5 | hilo
# Processing Record 26 of Set 5 | fabens
# Processing Record 27 of Set 5 | kapshagay
# City not found. Skipping...
# Processing Record 28 of Set 5 | torghay
# Processing Record 29 of Set 5 | jiayuguan
# Processing Record 30 of Set 5 | mancio lima
# Processing Record 31 of Set 5 | atafu village
# City not found. Skipping...
# Processing Record 32 of Set 5 | wanning
# Processing Record 33 of Set 5 | zhigalovo
# Processing Record 34 of Set 5 | plettenberg bay
# Processing Record 35 of Set 5 | corinto
# Processing Record 36 of Set 5 | aksu
# Processing Record 37 of Set 5 | ribeira brava
# Processing Record 38 of Set 5 | hermanus
# Processing Record 39 of Set 5 | troitsko-pechorsk
# Processing Record 40 of Set 5 | carrickfergus
# Processing Record 41 of Set 5 | tshabong
# Processing Record 42 of Set 5 | vera cruz
# Processing Record 43 of Set 5 | wynyard
# Processing Record 44 of Set 5 | novobelokatay
# Processing Record 45 of Set 5 | port macquarie
# Processing Record 46 of Set 5 | kavaratti
# Processing Record 47 of Set 5 | bardai
# Processing Record 48 of Set 5 | viedma
# Processing Record 49 of Set 5 | tolanaro
# Processing Record 0 of Set 6 | rehoboth
# Processing Record 1 of Set 6 | polyarnyy
# Processing Record 2 of Set 6 | port alfred
# Processing Record 3 of Set 6 | shetpe
# Processing Record 4 of Set 6 | yangjiang
# Processing Record 5 of Set 6 | ghat
# Processing Record 6 of Set 6 | constitucion
# Processing Record 7 of Set 6 | lata
# Processing Record 8 of Set 6 | azhikkal
# Processing Record 9 of Set 6 | huarmey
# Processing Record 10 of Set 6 | kalmunai
# Processing Record 11 of Set 6 | thunder bay
# Processing Record 12 of Set 6 | kirillov
# Processing Record 13 of Set 6 | rundu
# Processing Record 14 of Set 6 | albu kamal
# Processing Record 15 of Set 6 | midvagur
# Processing Record 16 of Set 6 | fale old settlement
# City not found. Skipping...
# Processing Record 17 of Set 6 | riebini
# City not found. Skipping...
# Processing Record 18 of Set 6 | ebon
# Processing Record 19 of Set 6 | pavlodol'skaya
# Processing Record 20 of Set 6 | guilin
# Processing Record 21 of Set 6 | haiku-pauwela
# Processing Record 22 of Set 6 | chul'man
# Processing Record 23 of Set 6 | aginskoye
# Processing Record 24 of Set 6 | nantucket
# Processing Record 25 of Set 6 | toliara
# Processing Record 26 of Set 6 | quellon
# Processing Record 27 of Set 6 | parun
# Processing Record 28 of Set 6 | stornoway
# Processing Record 29 of Set 6 | flin flon
# Processing Record 30 of Set 6 | chibougamau
# Processing Record 31 of Set 6 | mount gambier
# Processing Record 32 of Set 6 | odawara
# Processing Record 33 of Set 6 | mu'minobod
# Processing Record 34 of Set 6 | morinville
# Processing Record 35 of Set 6 | inayauan
# Processing Record 36 of Set 6 | san antonio de pale
# Processing Record 37 of Set 6 | kruisfontein
# Processing Record 38 of Set 6 | yerofey pavlovich
# Processing Record 39 of Set 6 | udachny
# Processing Record 40 of Set 6 | fish town
# Processing Record 41 of Set 6 | muynoq
# Processing Record 42 of Set 6 | nadi
# Processing Record 43 of Set 6 | thomson
# Processing Record 44 of Set 6 | tommot
# Processing Record 45 of Set 6 | cabo san lucas
# Processing Record 46 of Set 6 | sinop
# Processing Record 47 of Set 6 | portland
# Processing Record 48 of Set 6 | juegang
# Processing Record 49 of Set 6 | sao vicente
# Processing Record 0 of Set 7 | zaragoza
# Processing Record 1 of Set 7 | selfoss
# Processing Record 2 of Set 7 | acarau
# Processing Record 3 of Set 7 | buenaventura
# Processing Record 4 of Set 7 | boyolangu
# Processing Record 5 of Set 7 | saudarkrokur
# Processing Record 6 of Set 7 | dudinka
# Processing Record 7 of Set 7 | pisco
# Processing Record 8 of Set 7 | port saint john's
# Processing Record 9 of Set 7 | swan hill
# Processing Record 10 of Set 7 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 11 of Set 7 | oroqen zizhiqi
# Processing Record 12 of Set 7 | fort st. john
# Processing Record 13 of Set 7 | pacific grove
# Processing Record 14 of Set 7 | farafangana
# Processing Record 15 of Set 7 | wainwright
# Processing Record 16 of Set 7 | vondrozo
# Processing Record 17 of Set 7 | santana
# Processing Record 18 of Set 7 | inari
# Processing Record 19 of Set 7 | patong
# Processing Record 20 of Set 7 | camanducaia
# Processing Record 21 of Set 7 | as sulayyil
# Processing Record 22 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 23 of Set 7 | gereshk
# Processing Record 24 of Set 7 | ilaro
# Processing Record 25 of Set 7 | chonchi
# Processing Record 26 of Set 7 | queenstown
# Processing Record 1 of Set 9 | altai
# Processing Record 2 of Set 9 | coari
# Processing Record 3 of Set 9 | gadzhiyevo
# Processing Record 4 of Set 9 | atlantic beach
# Processing Record 5 of Set 9 | rabo de peixe
# Processing Record 6 of Set 9 | almenno san salvatore
# Processing Record 7 of Set 9 | jalai nur
# Processing Record 8 of Set 9 | guerrero negro
# Processing Record 9 of Set 9 | karasburg
# Processing Record 10 of Set 9 | corn island
# Processing Record 11 of Set 9 | nazyvayevsk
# Processing Record 12 of Set 9 | nuuk
# Processing Record 13 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 14 of Set 9 | wajir
# Processing Record 15 of Set 9 | nogliki
# Processing Record 16 of Set 9 | hammerfest
# Processing Record 17 of Set 9 | cockburn town
# Processing Record 18 of Set 9 | nagqu
# Processing Record 19 of Set 9 | mossel bay
# Processing Record 20 of Set 9 | la charite-sur-loire
# Processing Record 21 of Set 9 | luwuk
# Processing Record 22 of Set 9 | hakui
# Processing Record 23 of Set 9 | mount pearl
# Processing Record 24 of Set 9 | la passe
# Processing Record 25 of Set 9 | manga
# Processing Record 26 of Set 9 | manado
# Processing Record 27 of Set 9 | nova vicosa
# Processing Record 28 of Set 9 | veinticinco de mayo
# Processing Record 29 of Set 9 | pangoa
# Processing Record 30 of Set 9 | prince rupert
# Processing Record 31 of Set 9 | callao
# Processing Record 32 of Set 9 | kargasok
# Processing Record 33 of Set 9 | jingdezhen
# Processing Record 34 of Set 9 | curaca
# Processing Record 35 of Set 9 | san jose village
# City not found. Skipping...
# Processing Record 36 of Set 9 | san miguel chicaj
# Processing Record 37 of Set 9 | tazacorte
# Processing Record 38 of Set 9 | villa de cura
# Processing Record 39 of Set 9 | anahuac
# Processing Record 40 of Set 9 | lospalos
# Processing Record 41 of Set 9 | visakhapatnam
# Processing Record 42 of Set 9 | vadso
# Processing Record 43 of Set 9 | maraba
# Processing Record 44 of Set 9 | mangochi
# Processing Record 45 of Set 9 | rudbar
# Processing Record 46 of Set 9 | greendale
# Processing Record 47 of Set 9 | rosarito
# Processing Record 48 of Set 9 | jaguaribe
# Processing Record 49 of Set 9 | puerto lempira
# Processing Record 0 of Set 10 | taksimo
# Processing Record 1 of Set 10 | kenai
# Processing Record 2 of Set 10 | puerto cabezas
# Processing Record 3 of Set 10 | delice
# Processing Record 4 of Set 10 | kantang
# Processing Record 5 of Set 10 | san luis de la loma
# Processing Record 6 of Set 10 | leua
# Processing Record 7 of Set 10 | moranbah
# Processing Record 8 of Set 10 | barabai
# Processing Record 9 of Set 10 | tateyama
# Processing Record 10 of Set 10 | torbat-e jam
# Processing Record 11 of Set 10 | sault ste. marie
# Processing Record 12 of Set 10 | el sauzal de rodriguez
# Processing Record 13 of Set 10 | suva
# Processing Record 14 of Set 10 | mikun'
# Processing Record 15 of Set 10 | yebaishou
# Processing Record 16 of Set 10 | chipinge
# Processing Record 17 of Set 10 | yuzhno-kurilsk
# Processing Record 18 of Set 10 | burang
# Processing Record 19 of Set 10 | vila velha
# Processing Record 20 of Set 10 | chimoio
# Processing Record 21 of Set 10 | grand falls-windsor
# Processing Record 22 of Set 10 | worland
# Processing Record 23 of Set 10 | el porvenir
# Processing Record 24 of Set 10 | uliastay
# Processing Record 25 of Set 10 | beyneu
# Processing Record 26 of Set 10 | gamay
# Processing Record 27 of Set 10 | qal'at bishah
# City not found. Skipping...
# Processing Record 28 of Set 10 | sosnovka
# Processing Record 29 of Set 10 | kostanay
# Processing Record 30 of Set 10 | ketchikan
# Processing Record 31 of Set 10 | palikir - national government center
# Processing Record 32 of Set 10 | kardonikskaya
# Processing Record 33 of Set 10 | kuzhener
# Processing Record 34 of Set 10 | nikolayevsk-on-amure
# Processing Record 35 of Set 10 | magadan
# Processing Record 36 of Set 10 | makubetsu
# Processing Record 37 of Set 10 | ijuw
# City not found. Skipping...
# Processing Record 38 of Set 10 | ezhou
# Processing Record 39 of Set 10 | celestun
# Processing Record 40 of Set 10 | lae
# Processing Record 41 of Set 10 | knyaze-volkonskoye
# Processing Record 42 of Set 10 | kolokani
# Processing Record 43 of Set 10 | newman
# Processing Record 44 of Set 10 | pontianak
# Processing Record 45 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 46 of Set 10 | gritsovskiy
# Processing Record 47 of Set 10 | amursk
# Processing Record 48 of Set 10 | cide
# Processing Record 49 of Set 10 | weatherford
# Processing Record 0 of Set 11 | qarqaraly
# Processing Record 1 of Set 11 | tionk essil
# Processing Record 2 of Set 11 | coquimbo
# Processing Record 3 of Set 11 | santo antonio
# Processing Record 4 of Set 11 | fortuna
# Processing Record 5 of Set 11 | island harbour
# Processing Record 6 of Set 11 | abuyog
# Processing Record 7 of Set 11 | shaowu
# Processing Record 8 of Set 11 | el vigia
# Processing Record 9 of Set 11 | papao
# Processing Record 10 of Set 11 | vilyuysk
# Processing Record 11 of Set 11 | mahibadhoo
# Processing Record 12 of Set 11 | shingu
# Processing Record 13 of Set 11 | bubaque
# Processing Record 14 of Set 11 | pont rouge
# Processing Record 15 of Set 11 | praia da vitoria
# Processing Record 16 of Set 11 | urcos
# Processing Record 17 of Set 11 | qamdo
# Processing Record 18 of Set 11 | kyain seikgyi township
# City not found. Skipping...
# Processing Record 19 of Set 11 | tamanrasset
# Processing Record 20 of Set 11 | senillosa
# Processing Record 21 of Set 11 | ciudad lazaro cardenas
# Processing Record 22 of Set 11 | hami
# Processing Record 23 of Set 11 | usinsk
# Processing Record 24 of Set 11 | krasavino
# Processing Record 25 of Set 11 | sterling
# Processing Record 26 of Set 11 | aykhal
# Processing Record 27 of Set 11 | rawson
# Processing Record 28 of Set 11 | union
# Processing Record 29 of Set 11 | san felipe
# Processing Record 30 of Set 11 | tibati
# Processing Record 31 of Set 11 | la'ie
# Processing Record 32 of Set 11 | cartagena del chaira
# Processing Record 33 of Set 11 | khandyga
# Processing Record 34 of Set 11 | dunedin
# Processing Record 35 of Set 11 | mabaruma
# Processing Record 36 of Set 11 | talakan
# Processing Record 37 of Set 11 | kodinsk
# Processing Record 38 of Set 11 | coahuayana de hidalgo
# Processing Record 39 of Set 11 | richards bay
# Processing Record 40 of Set 11 | happy valley-goose bay
# Processing Record 41 of Set 11 | sarina
# Processing Record 42 of Set 11 | kisangani
# Processing Record 43 of Set 11 | broken hill
# Processing Record 44 of Set 11 | mauranwan
# Processing Record 45 of Set 11 | la ronge
# Processing Record 46 of Set 11 | langarud
# Processing Record 47 of Set 11 | capayan
# Processing Record 48 of Set 11 | mount isa
# Processing Record 49 of Set 11 | luanda
# Processing Record 0 of Set 12 | charters towers
# Processing Record 1 of Set 12 | buzias
# Processing Record 2 of Set 12 | santa marta
# Processing Record 3 of Set 12 | radyvyliv
# Processing Record 4 of Set 12 | guiglo
# Processing Record 5 of Set 12 | caucete
# Processing Record 6 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 12 | west helena
# Processing Record 8 of Set 12 | rio grande
# Processing Record 9 of Set 12 | khandud
# Processing Record 10 of Set 12 | porto novo
# Processing Record 11 of Set 12 | camabatela
# Processing Record 12 of Set 12 | villa avila camacho
# Processing Record 13 of Set 12 | antsiranana
# Processing Record 14 of Set 12 | las lomitas
# Processing Record 15 of Set 12 | itaituba
# Processing Record 16 of Set 12 | bartlesville
# Processing Record 17 of Set 12 | hayden
# Processing Record 18 of Set 12 | kavieng
# Processing Record 19 of Set 12 | rosales
# Processing Record 20 of Set 12 | sovetskaya gavan'
# Processing Record 21 of Set 12 | al matlin
# Processing Record 22 of Set 12 | novyy urgal
# Processing Record 23 of Set 12 | kanker
# Processing Record 24 of Set 12 | noumea
# Processing Record 25 of Set 12 | lamu
# Processing Record 26 of Set 12 | sabzevar
# Processing Record 27 of Set 12 | harnai
# Processing Record 28 of Set 12 | laguna
# Processing Record 29 of Set 12 | surovikino
# Processing Record 30 of Set 12 | pingnan
# Processing Record 31 of Set 12 | sompeta
# Processing Record 32 of Set 12 | nyurba
# Processing Record 33 of Set 12 | palanga
# Processing Record 34 of Set 12 | peniche
# Processing Record 35 of Set 12 | dunay
# Processing Record 36 of Set 12 | kitale
# Processing Record 37 of Set 12 | trancas
# Processing Record 38 of Set 12 | morehead city
# Processing Record 39 of Set 12 | sulphur springs
# Processing Record 40 of Set 12 | ixtapa
# Processing Record 41 of Set 12 | kabala
# Processing Record 42 of Set 12 | mumford
# Processing Record 43 of Set 12 | aleshtar
# Processing Record 44 of Set 12 | cable beach
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Created Dataframe and Scatterplotted latitude vs temperature

# %%
# Define Dataframe for cities and scatterplotted latitude vs temperature
city_data_df = pd.DataFrame(city_data)

plt.scatter(city_data_df["Lat"],city_data_df["Weather"])

plt.show()

plt.close()

# %% [markdown]
# ### Latitude vs Humidity

# %%
# scatterplot latitude vs humidity

plt.scatter(city_data_df["Lat"],city_data_df["Humidity"])

plt.show()

plt.close()

# %% [markdown]
# ### Latitude vs Cloudiness

# %%
# scatterplot latitude vs Cloudiness

plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"])

plt.show()

plt.close()

# %% [markdown]
# ### Latitude vs Wind Speed

# %%
# scatterplot latitude vs wind speed

plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"])

plt.show()

plt.close()

# %% [markdown]
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# create northern and southern hemisphere dataframes
north_hemisphere = city_data_df.loc[city_data_df["Lat"] >= 0]
south_hemisphere = city_data_df.loc[city_data_df["Lat"] <= 0]

# %%
# create a function for regression scatterplot
def getLinearRegression(x,y):
    print(f"The r-value is: {round(st.pearsonr(x,y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x,y)
    regress = x * slope + intercept
    result = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress,color='r',alpha=0.7)
    return result

def annotation(regress, left, top):
    plt.annotate(regress,(left,top),fontsize=12,color="blue")

# %% [markdown]
# #### Temperature vs Latitude Linear Regression Plot

# %%
# scatterplot northern hemipshere: temperature vs latitude
x_val = north_hemisphere["Lat"]
y_val = north_hemisphere["Weather"]
eq = getLinearRegression(x_val, y_val)

annotation(eq, 20, 20)
plt.xlabel("Lat")
plt.ylabel("Max Temp")

plt.show()

plt.close()
# Out:
# The r-value is: -0.81

# %%
# Linear regression on South Hemisphere
x_val = south_hemisphere["Lat"]
y_val = south_hemisphere["Max Temp"]
eq = getLinearRegression(x_val, y_val)

annotation(eq, -50, 80)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.show()

plt.close()
# Out:
# The r-value is: 0.77

# %% [markdown]
# #### There's a strong negative correlation and positive correlation between latitude and max temperature for north and south hemispheres respectively

# %% [markdown]
# #### Humidity vs Latitude Linear Regression Plot

# %%
# North Hemisphere
x_val = north_hemisphere["Lat"]
y_val = north_hemisphere["Humidity"]
eq = getLinearRegression(x_val, y_val)

annotation(eq, 50, 10)
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.show()

plt.close()
# Out:
# The r-value is: -0.05

# %%
# Linear regression on South Hemisphere
x_val = south_hemisphere["Lat"]
y_val = south_hemisphere["Humidity"]
eq = getLinearRegression(x_val, y_val)

annotation(eq, -50, 30)
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.show()

plt.close()
# Out:
# The r-value is: 0.22

# %% [markdown]
# ##### There's a weak negative correlation and a moderate positive correlation between latitude and humidity for north and south hemispheres respectively

# %% [markdown]
# #### Cloudiness vs Latitude Linear Regression Plot

# %%
# North Hemisphere
x_val = north_hemisphere["Lat"]
y_val = north_hemisphere["Cloudiness"]
eq = getLinearRegression(x_val, y_val)

annotation(eq, 10, 60)

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.show()

plt.close()
# Out:
# The r-value is: -0.02

# %%
# South Hemisphere
x_val = south_hemisphere["Lat"]
y_val = south_hemisphere["Cloudiness"]
eq = getLinearRegression(x_val, y_val)

annotation(eq, -50, 30)

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.show()
# Out:
# The r-value is: -0.0

# %% [markdown]
# There is almost no correlation between latitude and cloudiness for north and south hemispheres

# %% [markdown]
# #### Wind Speed vs Latitude Linear Regression Plot

# %%
# North Hemisphere
x_val = north_hemisphere["Lat"]
y_val = north_hemisphere["Wind Speed"]
eq = getLinearRegression(x_val, y_val)

annotation(eq, 20, 25)

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.show()

plt.close()
# Out:
# The r-value is: 0.14

# %%
# South Hemisphere
x_val = south_hemisphere["Lat"]
y_val = south_hemisphere["Wind Speed"]
eq = getLinearRegression(x_val, y_val)

annotation(eq, -35, 20)

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.show()

plt.close()
# Out:
# The r-value is: -0.21

# %% [markdown]
# #### There's a weak positive correlation and a weak negative correlation between latitude and wind speed for north and south hemispheres respectively
